# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
# Out:
# /usr/local/lib/python2.7/dist-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
words
# Out:
# ['the',
#  'of',
#  'and',
#  'one',
#  'in',
#  'a',
#  'to',
#  'zero',
#  'nine',
#  'two',
#  'is',
#  'as',
#  'eight',
#  'for',
#  's',
#  'five',
#  'three',
#  'was',
#  'by',
#  'that',
#  'four',
#  'six',
#  'seven',
#  'with',
#  'on',
#  'are',
#  'it',
#  'from',
#  'or',
#  'his',
#  'an',
#  'be',
#  'this',
#  'which',
#  'at',
#  'he',
#  'also',
#  'not',
#  'have',
#  'were',
#  'has',
#  'but',
#  'other',
#  'their',
#  'its',
#  'first',
#  'they',
#  'some',
#  'had',
#  'all',
#  'more',
#  'most',
#  'can',
#  'been',
#  'such',
#  'many',
#  'who',
#  'new',
#  'used',
#  'there',
#  'after',
#  'when',
#  'into',
#  'american',
#  'time',
#  'these',
#  'only',
#  'see',
#  'may',
#  'than',
#  'world',
#  'i',
#  'b',
#  'would',
#  'd',
#  'no',
#  'however',
#  'between',
#  'about',
#  'over',
#  'years',
#  'states',
#  'people',
#  'war',
#  'during',
#  'united',
#  'known',
#  'if',
#  'called',
#  'use',
#  'th',
#  'system',
#  'often',
#  'state',
#  'so',
#  'history',
#  'will',
#  'up',
#  'while',
#  'where',
#  'city',
#  'being',
#  'english',
#  'then',
#  'any',
#  'both',
#  'under',
#  'out',
#  'made',
#  'well',
#  'her',
#  'e',
#  'number',
#  'government',
#  'them',
#  'm',
#  'later',
#  'since',
#  'him',
#  'part',
#  'name',
#  'c',
#  'century',
#  'through',
#  'because',
#  'x',
#  'university',
#  'early',
#  'life',
#  'british',
#  'year',
#  'like',
#  'same',
#  'including',
#  'became',
#  'example',
#  'day',
#  'each',
#  'even',
#  'work',
#  'language',
#  'although',
#  'several',
#  'form',
#  'john',
#  'u',
#  'national',
#  'very',
#  'much',
#  'g',
#  'french',
#  'before',
#  'general',
#  'what',
#  't',
#  'against',
#  'n',
#  'high',
#  'links',
#  'could',
#  'based',
#  'those',
#  'now',
#  'second',
#  'de',
#  'music',
#  'another',
#  'large',
#  'she',
#  'f',
#  'external',
#  'german',
#  'different',
#  'modern',
#  'great',
#  'do',
#  'common',
#  'set',
#  'list',
#  'south',
#  'series',
#  'major',
#  'game',
#  'power',
#  'long',
#  'country',
#  'king',
#  'law',
#  'group',
#  'film',
#  'still',
#  'until',
#  'north',
#  'international',
#  'term',
#  'we',
#  'end',
#  'book',
#  'found',
#  'own',
#  'political',
#  'party',
#  'order',
#  'usually',
#  'president',
#  'church',
#  'you',
#  'death',
#  'theory',
#  'area',
#  'around',
#  'include',
#  'god',
#  'ii',
#  'way',
#  'did',
#  'military',
#  'population',
#  'using',
#  'though',
#  'small',
#  'following',
#  'within',
#  'non',
#  'left',
#  'human',
#  'main',
#  'among',
#  'point',
#  'r',
#  'due',
#  'p',
#  'considered',
#  'public',
#  'popular',
#  'computer',
#  'west',
#  'family',
#  'east',
#  'information',
#  'important',
#  'european',
#  'man',
#  'sometimes',
#  'right',
#  'old',
#  'free',
#  'word',
#  'without',
#  'last',
#  'us',
#  'members',
#  'given',
#  'times',
#  'roman',
#  'make',
#  'h',
#  'age',
#  'place',
#  'l',
#  'thus',
#  'science',
#  'case',
#  'become',
#  'systems',
#  'union',
#  'born',
#  'york',
#  'line',
#  'countries',
#  'does',
#  'isbn',
#  'st',
#  'control',
#  'various',
#  'others',
#  'house',
#  'article',
#  'island',
#  'should',
#  'led',
#  'back',
#  'period',
#  'player',
#  'europe',
#  'languages',
#  'central',
#  'water',
#  'few',
#  'western',
#  'home',
#  'began',
#  'generally',
#  'less',
#  'k',
#  'similar',
#  'written',
#  'original',
#  'best',
#  'must',
#  'according',
#  'school',
#  'france',
#  'air',
#  'single',
#  'force',
#  'v',
#  'land',
#  'groups',
#  'down',
#  'how',
#  'works',
#  'development',
#  'official',
#  'support',
#  'england',
#  'j',
#  'rather',
#  'data',
#  'space',
#  'greek',
#  'km',
#  'named',
#  'germany',
#  'just',
#  'games',
#  'said',
#  'version',
#  'late',
#  'earth',
#  'company',
#  'every',
#  'economic',
#  'short',
#  'published',
#  'black',
#  'army',
#  'off',
#  'london',
#  'million',
#  'body',
#  'field',
#  'christian',
#  'either',
#  'social',
#  'empire',
#  'o',
#  'developed',
#  'standard',
#  'court',
#  'service',
#  'kingdom',
#  'along',
#  'college',
#  'republic',
#  'sea',
#  'america',
#  'today',
#  'result',
#  'held',
#  'team',
#  'light',
#  'means',
#  'never',
#  'especially',
#  'third',
#  'further',
#  'forces',
#  'character',
#  'take',
#  'men',
#  'society',
#  'show',
#  'open',
#  'possible',
#  'fact',
#  'battle',
#  'took',
#  'former',
#  'books',
#  'soviet',
#  'river',
#  'children',
#  'having',
#  'good',
#  'local',
#  'current',
#  'son',
#  'process',
#  'natural',
#  'present',
#  'himself',
#  'islands',
#  'total',
#  'near',
#  'white',
#  'days',
#  'person',
#  'itself',
#  'seen']

# %%
filename
# Out:
# 'text8.zip'

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
print (dictionary['two'])
print (reverse_dictionary[10])
# Out:
# 10
# two

# %%
data
# Out:
# [5239,
#  3084,
#  12,
#  6,
#  195,
#  2,
#  3137,
#  46,
#  59,
#  156,
#  128,
#  742,
#  477,
#  10572,
#  134,
#  1,
#  27549,
#  2,
#  1,
#  103,
#  855,
#  3,
#  1,
#  15068,
#  0,
#  2,
#  1,
#  151,
#  855,
#  3583,
#  1,
#  195,
#  11,
#  191,
#  59,
#  5,
#  6,
#  10742,
#  215,
#  7,
#  1326,
#  105,
#  455,
#  20,
#  59,
#  2734,
#  363,
#  7,
#  3676,
#  1,
#  709,
#  2,
#  372,
#  27,
#  41,
#  37,
#  54,
#  541,
#  98,
#  12,
#  6,
#  1426,
#  2760,
#  19,
#  568,
#  687,
#  7106,
#  1,
#  248,
#  5239,
#  11,
#  1053,
#  28,
#  1,
#  321,
#  249,
#  45311,
#  2880,
#  793,
#  187,
#  5239,
#  12,
#  6,
#  201,
#  603,
#  11,
#  1,
#  1136,
#  20,
#  2623,
#  26,
#  9015,
#  3,
#  280,
#  32,
#  4154,
#  142,
#  60,
#  26,
#  6446,
#  4198,
#  2,
#  154,
#  33,
#  363,
#  5239,
#  37,
#  1138,
#  7,
#  448,
#  345,
#  1819,
#  20,
#  4863,
#  1,
#  6766,
#  2,
#  7592,
#  1776,
#  567,
#  1,
#  94,
#  1,
#  248,
#  11104,
#  12,
#  52,
#  7106,
#  90,
#  27,
#  271,
#  38,
#  5954,
#  4870,
#  20522,
#  29,
#  0,
#  42,
#  318,
#  6,
#  25772,
#  528,
#  7592,
#  372,
#  5,
#  259,
#  2,
#  154,
#  26,
#  1207,
#  12,
#  7592,
#  201,
#  1581,
#  3,
#  15341,
#  333,
#  1776,
#  7106,
#  4863,
#  345,
#  765,
#  161,
#  407,
#  5697,
#  756,
#  2,
#  4117,
#  1133,
#  4341,
#  1537,
#  3,
#  568,
#  8125,
#  99,
#  5239,
#  11,
#  52,
#  1409,
#  687,
#  19,
#  154,
#  27,
#  11,
#  156,
#  7106,
#  37,
#  2035,
#  1426,
#  8175,
#  2,
#  154,
#  47,
#  695,
#  7,
#  32,
#  6,
#  4153,
#  247,
#  372,
#  77,
#  949,
#  79,
#  311,
#  31,
#  4786,
#  372,
#  509,
#  140,
#  2315,
#  3555,
#  365,
#  24,
#  1822,
#  7,
#  1905,
#  60,
#  11,
#  37,
#  8431,
#  79,
#  311,
#  6,
#  247,
#  372,
#  509,
#  32,
#  754,
#  79,
#  1738,
#  3,
#  8081,
#  24433,
#  3,
#  276,
#  1694,
#  20,
#  152,
#  1033,
#  96,
#  226,
#  372,
#  18,
#  1814,
#  25,
#  4786,
#  1557,
#  52,
#  8136,
#  1468,
#  24433,
#  3,
#  12752,
#  5,
#  6139,
#  20,
#  4196,
#  21197,
#  2430,
#  40,
#  16595,
#  3,
#  7252,
#  862,
#  2,
#  1195,
#  10248,
#  2516,
#  29,
#  15186,
#  188,
#  3,
#  49,
#  1124,
#  913,
#  7,
#  1050,
#  470,
#  12360,
#  7106,
#  134,
#  1,
#  1,
#  11104,
#  3056,
#  3,
#  12137,
#  735,
#  4786,
#  6605,
#  5,
#  14630,
#  28,
#  451,
#  486,
#  24433,
#  199,
#  296,
#  949,
#  5,
#  20280,
#  20559,
#  2,
#  0,
#  301,
#  7,
#  24433,
#  20559,
#  16575,
#  1,
#  30385,
#  2,
#  1,
#  94,
#  45,
#  3837,
#  3,
#  0,
#  3,
#  3811,
#  1,
#  3417,
#  2,
#  1,
#  1782,
#  188,
#  2,
#  1,
#  626,
#  1,
#  13179,
#  2,
#  4,
#  22,
#  91,
#  123,
#  285,
#  26,
#  244,
#  233,
#  7,
#  32,
#  437,
#  26474,
#  2,
#  174,
#  5239,
#  7729,
#  2535,
#  5,
#  30,
#  96,
#  2,
#  290,
#  603,
#  4318,
#  20,
#  1,
#  13179,
#  16575,
#  50,
#  188,
#  118,
#  47,
#  360,
#  20,
#  1,
#  385,
#  243,
#  97,
#  32,
#  5235,
#  35,
#  332,
#  2725,
#  19,
#  1,
#  839,
#  1378,
#  28,
#  33,
#  8763,
#  47,
#  6487,
#  35,
#  3246,
#  1,
#  27549,
#  29,
#  552,
#  42594,
#  40,
#  31,
#  128,
#  0,
#  436,
#  85,
#  1,
#  65,
#  2,
#  1,
#  103,
#  464,
#  84,
#  3,
#  26,
#  233,
#  19,
#  48,
#  12,
#  26474,
#  2,
#  174,
#  5239,
#  5,
#  1,
#  174,
#  840,
#  1,
#  46,
#  7,
#  90,
#  1,
#  195,
#  7,
#  1015,
#  1044,
#  43,
#  70,
#  4870,
#  18,
#  937,
#  15001,
#  4572,
#  165,
#  0,
#  5,
#  30,
#  40800,
#  11878,
#  23109,
#  260,
#  1226,
#  0,
#  0,
#  4,
#  23,
#  8,
#  17,
#  100,
#  36,
#  629,
#  1,
#  2666,
#  64,
#  372,
#  34,
#  49,
#  76,
#  94,
#  688,
#  14845,
#  4051,
#  29,
#  818,
#  918,
#  12,
#  102,
#  5,
#  11104,
#  2535,
#  363,
#  6,
#  6070,
#  3,
#  664,
#  5,
#  1,
#  64,
#  702,
#  436,
#  41,
#  4228,
#  1290,
#  20,
#  36,
#  11,
#  31,
#  4786,
#  3,
#  95,
#  26,
#  50,
#  30,
#  5229,
#  5,
#  4,
#  23,
#  9,
#  17,
#  5,
#  1,
#  5351,
#  2,
#  1,
#  151,
#  855,
#  470,
#  12360,
#  335,
#  31,
#  17307,
#  2435,
#  201,
#  1294,
#  142,
#  12360,
#  216,
#  38,
#  90,
#  1,
#  248,
#  5239,
#  56,
#  117,
#  7106,
#  39,
#  1207,
#  33,
#  198,
#  12,
#  1,
#  46,
#  182,
#  4786,
#  530,
#  3,
#  12360,
#  12,
#  1,
#  1836,
#  2,
#  1913,
#  5239,
#  42,
#  35,
#  33,
#  229,
#  76,
#  4786,
#  436,
#  734,
#  2400,
#  3,
#  1,
#  195,
#  0,
#  18,
#  87,
#  1074,
#  12,
#  31,
#  14159,
#  30460,
#  19,
#  1,
#  12090,
#  0,
#  35,
#  51,
#  2423,
#  617,
#  5,
#  1,
#  151,
#  855,
#  1,
#  46,
#  568,
#  8740,
#  4786,
#  2939,
#  1034,
#  14566,
#  27,
#  11,
#  637,
#  360,
#  20,
#  27,
#  5401,
#  155,
#  192,
#  2939,
#  1034,
#  14566,
#  335,
#  154,
#  11,
#  918,
#  5,
#  4,
#  13,
#  21,
#  8,
#  20,
#  1,
#  195,
#  4786,
#  18,
#  991,
#  12,
#  6,
#  568,
#  1610,
#  27,
#  11,
#  14,
#  33,
#  891,
#  20,
#  48,
#  849,
#  14566,
#  12,
#  1,
#  1836,
#  2,
#  174,
#  4786,
#  209,
#  5,
#  154,
#  11,
#  918,
#  14566,
#  5470,
#  24,
#  1,
#  420,
#  12995,
#  918,
#  11,
#  6902,
#  5,
#  33,
#  140,
#  36,
#  1347,
#  1,
#  2881,
#  2,
#  15186,
#  918,
#  0,
#  155,
#  100,
#  3470,
#  39,
#  653,
#  446,
#  7,
#  90,
#  3,
#  3137,
#  44,
#  918,
#  12,
#  47,
#  3595,
#  55,
#  12,
#  15358,
#  1556,
#  14,
#  2969,
#  5,
#  45,
#  259,
#  14566,
#  1165,
#  154,
#  36,
#  89,
#  3226,
#  1133,
#  53,
#  39,
#  752,
#  446,
#  7,
#  90,
#  1050,
#  523,
#  3,
#  1793,
#  5,
#  5810,
#  24,
#  1557,
#  2,
#  5131,
#  3,
#  1294,
#  14566,
#  15,
#  2655,
#  2,
#  11104,
#  34,
#  36,
#  89,
#  29797,
#  0,
#  968,
#  31,
#  1335,
#  519,
#  100,
#  1133,
#  3,
#  309,
#  160,
#  513,
#  1,
#  807,
#  2,
#  44,
#  1259,
#  219,
#  1259,
#  1038,
#  34,
#  1392,
#  1,
#  909,
#  2,
#  742,
#  65,
#  968,
#  5,
#  443,
#  33,
#  74,
#  2918,
#  20,
#  76,
#  4,
#  74,
#  2969,
#  28,
#  1,
#  1259,
#  2,
#  276,
#  1556,
#  160,
#  4322,
#  2521,
#  499,
#  5,
#  728,
#  10686,
#  18880,
#  31,
#  763,
#  247,
#  987,
#  74,
#  32,
#  178,
#  98,
#  7,
#  741,
#  3273,
#  24,
#  913,
#  7,
#  1,
#  363,
#  2,
#  443,
#  14566,
#  15,
#  949,
#  40,
#  2026,
#  223,
#  151,
#  742,
#  477,
#  1819,
#  3,
#  30,
#  2987,
#  40,
#  1023,
#  5,
#  1,
#  855,
#  2,
#  4,
#  13,
#  21,
#  13,
#  5,
#  303,
#  14566,
#  15,
#  603,
#  2,
#  918,
#  11,
#  648,
#  27,
#  18,
#  348,
#  5,
#  6,
#  113,
#  2,
#  312,
#  80,
#  30,
#  3573,
#  3,
#  60,
#  26,
#  6446,
#  4198,
#  2,
#  48,
#  2,
#  30,
#  949,
#  14,
#  51,
#  2161,
#  1590,
#  68,
#  622,
#  2751,
#  26256,
#  15,
#  15649,
#  5,
#  30,
#  1,
#  10491,
#  3,
#  45,
#  200,
#  26256,
#  1462,
#  20,
#  52,
#  637,
#  1047,
#  345,
#  1776,
#  134,
#  1,
#  2582,
#  2,
#  94,
#  918,
#  12,
#  6,
#  245,
#  390,
#  446,
#  5,
#  153,
#  3,
#  1,
#  148,
#  2582,
#  2,
#  372,
#  40,
#  4594,
#  21074,
#  29,
#  9227,
#  5,
#  1,
#  941,
#  1977,
#  2,
#  372,
#  20,
#  1,
#  1133,
#  26,
#  45,
#  1730,
#  36,
#  5219,
#  15649,
#  3,
#  6,
#  144,
#  2,
#  0,
#  5,
#  34,
#  1133,
#  74,
#  9742,
#  5,
#  5834,
#  2,
#  0,
#  67,
#  62,
#  27,
#  18,
#  5,
#  44,
#  568,
#  763,
#  7,
#  176,
#  95,
#  14,
#  119,
#  918,
#  685,
#  1146,
#  79,
#  124,
#  509,
#  13044,
#  5577,
#  311,
#  7,
#  370,
#  7,
#  4107,
#  1,
#  1798,
#  7,
#  119,
#  5471,
#  918,
#  3,
#  154,
#  72,
#  39,
#  5,
#  609,
#  184,
#  20,
#  11,
#  609,
#  200,
#  95,
#  185,
#  12,
#  72,
#  6194,
#  9058,
#  12,
#  7205,
#  72,
#  1226,
#  1,
#  33812,
#  2,
#  1,
#  1798,
#  26256,
#  364,
#  89,
#  392,
#  31,
#  4786,
#  36,
#  1047,
#  67,
#  1,
#  2760,
#  43240,
#  2072,
#  30,
#  949,
#  40,
#  2026,
#  25,
#  56,
#  0,
#  9947,
#  7106,
#  142,
#  4198,
#  2,
#  30,
#  502,
#  26,
#  3239,
#  ...]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  #num_skips determines how many times to re-use a input
  #skip_window determines the number of targets for each input
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'term', 'anarchism', 'originated', 'originated', 'of', 'as', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  #valid_dataset is a list of word (indices)
  #embeddings are the embeddins of all words, embedding_lookup find the embeddings for each word
  #valid_embeddings is the embeddings of the valid dataset
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  #the result of similarity is the likelyhood of each word being the context of the valid word
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.209051
# Nearest to to: datatypes, attempts, droll, gogh, elmo, quo, among, pancras,
# Nearest to first: jed, gained, eller, deferred, tier, saya, cho, nouvelle,
# Nearest to he: dissent, contraction, supernaturalism, headset, harmless, california, hutu, tributes,
# Nearest to can: incarnate, atrocity, micrograms, totalitarianism, obliged, austria, vdp, taiping,
# Nearest to they: officer, bomis, transformative, ima, unicef, abolition, adrift, vectorborne,
# Nearest to with: survived, slowdown, player, sanj, purposely, lymphocyte, cellos, convex,
# Nearest to their: vegeta, instrument, hacks, ecs, darling, centrioles, accomplishment, pamela,
# Nearest to time: shipwrecked, size, backwardness, arleigh, bequeathed, disappearance, eastwards, iraqi,
# Nearest to have: cuyp, niche, illuminating, widower, aunts, bijection, rijeka, assemblers,
# Nearest to s: solent, khazar, antikythera, rodney, fission, sensation, tte, vicious,
# Nearest to b: belize, stalk, profess, namespace, kitsch, collapsing, questions, prophylactic,
# Nearest to th: tsarina, gpled, reintroducing, customarily, tsar, obscure, demoscene, rummel,
# Nearest to many: served, tzow, ligases, eel, yeomen, awaken, probabilities, shema,
# Nearest to if: fredrik, mythology, wait, thorium, hyperion, ciliates, jazz, nameserver,
# Nearest to is: crioulo, endymion, pathogen, expert, cu, obstacles, montfort, photographed,
# Nearest to may: hing, convening, circumnavigation, amenities, elaine, heightened, willingly, shoes,
# Average loss at step 2000: 4.363683
# Average loss at step 4000: 3.867493
# Average loss at step 6000: 3.784691
# Average loss at step 8000: 3.687884
# Average loss at step 10000: 3.619042
# Nearest to to: not, ligands, memes, benton, effectively, would, patience, vaccines,
# Nearest to first: jed, gained, latter, pinnacle, dc, terrain, legalized, methylene,
# Nearest to he: it, they, she, who, that, but, bok, pickles,
# Nearest to can: cannot, would, may, could, will, rickshaws, ostrich, thence,
# Nearest to they: he, it, we, who, she, there, not, brunt,
# Nearest to with: into, during, in, between, by, for, patrolled, unaware,
# Nearest to their: his, its, her, the, hacks, this, speeches, vilified,
# Nearest to time: chuck, eastwards, easiest, glace, zak, size, best, ever,
# Nearest to have: be, has, had, are, were, do, undertaken, aunts,
# Nearest to s: his, solent, isbn, or, wien, mohammed, and, scraping,
# Nearest to b: d, kitsch, laptop, catalana, prophylactic, bru, vortex, answered,
# Nearest to th: dressage, customarily, novelty, tsarina, seven, gpled, three, explicitly,
# Nearest to many: some, several, yeomen, served, pulau, apollon, these, different,
# Nearest to if: fredrik, does, proven, transporters, ciliates, when, congratulated, mythology,
# Nearest to is: was, are, has, be, photographed, vinge, mohammed, were,
# Nearest to may: can, would, willingly, must, will, hing, basque, charlton,
# Average loss at step 12000: 3.605376
# Average loss at step 14000: 3.568186
# Average loss at step 16000: 3.403382
# Average loss at step 18000: 3.457818
# Average loss at step 20000: 3.541248
# Nearest to to: memes, would, not, infractions, giving, will, can, may,
# Nearest to first: second, jed, latter, pinnacle, dc, wiccans, glacier, burg,
# Nearest to he: it, she, they, who, there, then, bok, this,
# Nearest to can: would, may, will, cannot, could, must, should, might,
# Nearest to they: he, there, we, it, who, she, bok, canisters,
# Nearest to with: in, into, between, using, for, during, or, patrolled,
# Nearest to their: his, its, her, the, some, dashboard, our, passwords,
# Nearest to time: eastwards, chuck, day, size, zak, case, barrett, took,
# Nearest to have: had, has, were, are, be, gallup, do, bata,
# Nearest to s: isbn, flourishing, bugtraq, knightly, lauded, scraping, komm, infantry,
# Nearest to b: d, kitsch, juvenile, thurber, prophylactic, laptop, coloane, spake,
# Nearest to th: dressage, customarily, novelty, chaplin, tsar, gpled, tsarina, tigre,
# Nearest to many: several, some, these, other, all, yeomen, especially, disassembly,
# Nearest to if: when, does, subsequent, fredrik, ammianus, gained, ciliates, currency,
# Nearest to is: was, are, has, were, but, redistricting, etudes, at,
# Nearest to may: can, would, will, should, could, must, immigrate, to,
# Average loss at step 22000: 3.502918
# Average loss at step 24000: 3.487255
# Average loss at step 26000: 3.476229
# Average loss at step 28000: 3.479411
# Average loss at step 30000: 3.504023
# Nearest to to: would, can, not, will, must, could, neuch, governorates,
# Nearest to first: second, last, latter, pinnacle, dc, same, mover, jed,
# Nearest to he: it, she, they, there, who, bok, parrot, profiling,
# Nearest to can: may, would, could, will, cannot, must, should, might,
# Nearest to they: there, we, he, it, these, who, you, she,
# Nearest to with: between, in, against, into, by, using, during, bombardier,
# Nearest to their: its, his, her, the, these, our, some, dashboard,
# Nearest to time: day, eastwards, year, chuck, zak, barrett, tat, size,
# Nearest to have: had, has, are, were, be, include, bata, do,
# Nearest to s: his, isbn, flourishing, beetles, famer, wien, akkadian, knightly,
# Nearest to b: d, juvenile, grasped, kitsch, presbyterians, sparky, brythonic, spake,
# Nearest to th: dressage, six, chaplin, zero, eight, nd, novelty, bc,
# Nearest to many: some, several, these, other, yeomen, most, various, such,
# Nearest to if: when, where, gained, does, transporters, though, ciliates, but,
# Nearest to is: was, has, are, be, does, although, while, became,
# Nearest to may: can, would, will, could, must, should, might, cannot,
# Average loss at step 32000: 3.501352
# Average loss at step 34000: 3.494055
# Average loss at step 36000: 3.456676
# Average loss at step 38000: 3.305201
# Average loss at step 40000: 3.427408
# Nearest to to: will, would, could, can, in, gogh, datatypes, serbian,
# Nearest to first: second, next, last, dc, latter, clears, same, third,
# Nearest to he: she, it, they, there, who, parrot, i, we,
# Nearest to can: may, will, could, would, must, cannot, should, might,
# Nearest to they: we, there, he, you, it, these, she, who,
# Nearest to with: between, when, predictable, culmination, broch, against, rapes, broke,
# Nearest to their: its, his, her, these, some, our, dashboard, any,
# Nearest to time: day, year, took, eastwards, striker, ever, barrett, chuck,
# Nearest to have: has, had, be, were, are, bata, gallup, editorship,
# Nearest to s: his, operates, kohlberg, bhaskara, aeolus, isbn, earldom, orchestrated,
# Nearest to b: d, r, conceptions, f, sparky, presbyterians, brythonic, m,
# Nearest to th: five, dressage, chaplin, nd, innings, thyssen, lesbian, moonlight,
# Nearest to many: some, several, these, various, those, existential, most, each,
# Nearest to if: when, where, ciliates, though, menorah, fredrik, gorge, cavalcanti,
# Nearest to is: was, are, has, be, gives, reorganised, kut, pact,
# Nearest to may: can, will, would, could, must, should, might, cannot,
# Average loss at step 42000: 3.431633
# Average loss at step 44000: 3.455559
# Average loss at step 46000: 3.452704
# Average loss at step 48000: 3.351882
# Average loss at step 50000: 3.379470
# Nearest to to: could, infractions, would, flatted, may, gogh, can, polity,
# Nearest to first: second, next, last, dc, third, jaffa, clears, old,
# Nearest to he: she, it, they, there, who, this, i, parrot,
# Nearest to can: may, could, will, would, must, cannot, should, might,
# Nearest to they: he, there, we, it, you, she, who, pratyeka,
# Nearest to with: between, by, against, logarithms, pataki, alg, when, orie,
# Nearest to their: its, his, her, our, the, these, some, dashboard,
# Nearest to time: year, day, barrett, eastwards, way, days, striker, chuck,
# Nearest to have: had, has, were, be, are, spanned, bata, who,
# Nearest to s: and, wi, isbn, countable, his, her, penetrated, keralites,
# Nearest to b: d, r, f, conceptions, sparky, wildcats, briefing, almagro,
# Nearest to th: nd, chaplin, innings, dressage, five, bc, three, lesbian,
# Nearest to many: some, several, these, various, those, both, other, all,
# Nearest to if: when, where, though, although, before, gorge, gained, say,
# Nearest to is: was, has, are, becomes, be, became, deadites, helpers,
# Nearest to may: can, will, would, could, should, must, might, cannot,
# Average loss at step 52000: 3.433360
# Average loss at step 54000: 3.428328
# Average loss at step 56000: 3.442050
# Average loss at step 58000: 3.397382
# Average loss at step 60000: 3.393666
# Nearest to to: gogh, sown, would, infractions, cannot, hypothesizing, might, not,
# Nearest to first: second, next, last, latter, third, dc, same, tischendorf,
# Nearest to he: she, it, they, there, who, we, belzec, alboin,
# Nearest to can: may, could, would, will, must, should, cannot, might,
# Nearest to they: we, there, he, you, she, it, pratyeka, i,
# Nearest to with: between, when, logarithms, broke, pataki, against, verona, norah,
# Nearest to their: its, his, her, the, our, some, dashboard, these,
# Nearest to time: barrett, year, day, eastwards, prophecy, size, maquis, season,
# Nearest to have: has, had, are, were, include, contain, be, bata,
# Nearest to s: angiosperms, although, wien, isbn, exhausts, says, animosity, earldom,
# Nearest to b: d, f, r, n, p, m, phonemes, conceptions,
# Nearest to th: six, five, bc, four, nd, rd, chaplin, dressage,
# Nearest to many: some, several, these, various, all, both, those, most,
# Nearest to if: when, where, though, although, perhaps, before, since, is,
# Nearest to is: was, are, has, although, rhythms, if, when, firemen,
# Nearest to may: can, would, will, should, could, must, might, cannot,
# Average loss at step 62000: 3.233342
# Average loss at step 64000: 3.258033
# Average loss at step 66000: 3.400455
# Average loss at step 68000: 3.391776
# Average loss at step 70000: 3.356557
# Nearest to to: will, would, must, ligands, cannot, sown, syndicalist, can,
# Nearest to first: second, next, last, third, same, latter, dc, best,
# Nearest to he: she, it, they, there, we, who, alboin, bok,
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Nearest to they: we, he, there, you, it, she, pratyeka, these,
# Nearest to with: between, using, against, in, makes, slowdown, broke, logarithms,
# Nearest to their: its, his, her, the, some, our, these, your,
# Nearest to time: year, barrett, eastwards, round, day, feats, prophecy, completion,
# Nearest to have: had, has, are, were, contain, be, include, bata,
# Nearest to s: isbn, intertwined, earldom, mohammed, arian, bugtraq, counterattacks, benevolent,
# Nearest to b: f, d, r, n, p, phonemes, e, conceptions,
# Nearest to th: bc, six, rd, four, five, chaplin, fifth, nd,
# Nearest to many: some, several, these, various, all, both, most, each,
# Nearest to if: when, where, though, although, before, however, while, zoroastrian,
# Nearest to is: was, has, are, be, although, makes, oneida, does,
# Nearest to may: can, will, would, should, could, might, must, cannot,
# Average loss at step 72000: 3.372277
# Average loss at step 74000: 3.348858
# Average loss at step 76000: 3.319596
# Average loss at step 78000: 3.349729
# Average loss at step 80000: 3.374479
# Nearest to to: will, would, gogh, memes, cannot, should, must, datatypes,
# Nearest to first: second, last, next, third, same, dc, fourth, feast,
# Nearest to he: she, it, they, there, who, we, alboin, burton,
# Nearest to can: could, may, will, must, would, should, cannot, might,
# Nearest to they: we, he, there, you, she, it, pratyeka, who,
# Nearest to with: between, during, in, when, originality, verona, logarithms, against,
# Nearest to their: its, his, her, our, your, the, dashboard, my,
# Nearest to time: year, day, took, eastwards, barrett, completion, stalingrad, round,
# Nearest to have: had, has, are, be, were, include, contain, having,
# Nearest to s: isbn, infantry, treating, generalizations, animosity, counterattacks, operates, zhu,
# Nearest to b: d, f, r, c, phonemes, cor, wildcats, n,
# Nearest to th: bc, rd, five, nd, six, fifth, chaplin, innings,
# Nearest to many: some, several, various, these, both, all, most, numerous,
# Nearest to if: when, though, before, where, although, perhaps, since, then,
# Nearest to is: was, has, becomes, are, although, became, remains, be,
# Nearest to may: can, will, would, could, must, should, might, cannot,
# Average loss at step 82000: 3.405203
# Average loss at step 84000: 3.409780
# Average loss at step 86000: 3.388751
# Average loss at step 88000: 3.348573
# Average loss at step 90000: 3.366120
# Nearest to to: will, would, datatypes, must, towards, infractions, gogh, hypothesizing,
# Nearest to first: second, last, next, third, latter, past, lodges, dc,
# Nearest to he: she, it, they, there, who, later, we, but,
# Nearest to can: could, may, will, must, would, should, might, cannot,
# Nearest to they: we, there, he, she, you, it, pratyeka, but,
# Nearest to with: between, in, decompose, poincar, tsunamis, by, lectionis, londonderry,
# Nearest to their: its, his, her, your, our, my, whose, the,
# Nearest to time: eastwards, took, day, completion, year, decade, barrett, stalingrad,
# Nearest to have: had, has, were, are, be, include, having, bata,
# Nearest to s: earldom, isbn, animosity, whose, schuster, barge, his, gallardo,
# Nearest to b: d, f, r, c, n, wildcats, cor, juvenile,
# Nearest to th: bc, fifth, rd, nd, seven, six, chaplin, eight,
# Nearest to many: some, several, various, these, all, most, numerous, clowns,
# Nearest to if: when, where, though, before, since, although, suppose, for,
# Nearest to is: was, has, are, makes, although, be, becomes, became,
# Nearest to may: could, can, will, would, should, must, might, cannot,
# Average loss at step 92000: 3.397597
# Average loss at step 94000: 3.247359
# Average loss at step 96000: 3.357056
# Average loss at step 98000: 3.240344
# Average loss at step 100000: 3.357437
# Nearest to to: will, should, could, can, would, must, may, infractions,
# Nearest to first: second, last, next, third, latter, feast, fourth, best,
# Nearest to he: she, it, they, there, we, who, i, this,
# Nearest to can: could, may, will, must, would, should, might, cannot,
# Nearest to they: we, he, there, you, she, it, pratyeka, i,
# Nearest to with: between, including, using, makes, workman, pataki, londonderry, through,
# Nearest to their: its, his, her, your, the, our, dashboard, whose,
# Nearest to time: year, day, completion, decade, eastwards, took, crag, negara,
# Nearest to have: had, has, are, were, include, be, contain, provide,
# Nearest to s: his, whose, animosity, kees, outback, counterattacks, her, punks,
# Nearest to b: d, juvenile, oops, slovak, incisors, verdeans, r, shank,
# Nearest to th: rd, bc, fifth, nd, innings, seventh, lau, chaplin,
# Nearest to many: several, some, various, these, numerous, clowns, all, few,
# Nearest to if: when, where, though, before, because, whether, since, while,
# Nearest to is: was, has, became, are, be, becomes, were, contains,
# Nearest to may: can, could, should, would, must, might, will, cannot,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
